# %%
#Importing all libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from torch import optim

# %%
# Importing libraries related to neurala networks
import torch
import torch.nn as nn
import os
from os import listdir
from os.path import isfile, join
from torch.utils import data
import torchvision
import torchvision.transforms as transforms
import PIL.Image as Image
from math import e
import torch.nn.functional as F
import itertools
import random
from torchvision import datasets, transforms

# %%
# Defining the Dataset
class SNN_Dataset(data.Dataset):
    def __init__(self, root, ME_DIR, NOT_ME_DIR):
        self.root = root
        ME_PATHS = listdir(ME_DIR)
        NOT_ME_PATHS = listdir(NOT_ME_DIR)
        ME_PATHS = [join(ME_DIR, img_path) for img_path in ME_PATHS]
        NOT_ME_PATHS = [join(NOT_ME_DIR, img_path) for img_path in NOT_ME_PATHS]
        ME_PAIRS = list(itertools.permutations(ME_PATHS, 2))
        self.TRIPLETS = list(itertools.product(ME_PAIRS, NOT_ME_PATHS))
        self.TRIPLETS = [list(triplet) for triplet in self.TRIPLETS]
        for i in range(len(self.TRIPLETS)):
            self.TRIPLETS[i] = list(self.TRIPLETS[i])
            self.TRIPLETS[i][0] = list(self.TRIPLETS[i][0])
            self.TRIPLETS[i][0].append(self.TRIPLETS[i][1])
            self.TRIPLETS[i].pop(-1)
            self.TRIPLETS[i] = self.TRIPLETS[i][0]
        random.shuffle(self.TRIPLETS)
    def __getitem__(self, index):
        img_triplet = [Image.open(img).convert('RGB') for img in self.TRIPLETS[index]]
        img_triplet = [transforms.Scale((244, 244))(img) for img in img_triplet]
        img_triplet = [transforms.ToTensor()(img) for img in img_triplet]
        return img_triplet[0], img_triplet[1], img_triplet[2]
    def __len__(self):
        return self.TRIPLETS

# %%
snn_dataset = SNN_Dataset(r"C:\Users\user\Desktop\cursuri 2021\AI\fotos",
 r"C:\Users\user\Desktop\cursuri 2021\AI\fotos\ME",
 r"C:\Users\user\Desktop\cursuri 2021\AI\fotos\NOT_ME")

# %%
# Creating the data laoder.
snn_loader = torch.utils.data.DataLoader(
    snn_dataset,
    batch_size=1,
    num_workers=2
)

# %%
# Creating the CNN
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        self.maxpool1 = nn.MaxPool2d(3, stride=1)
        self.conv1_dropuot = nn.Dropout2d(0.5)
        self.comv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.conv2_dropuot = nn.Dropout2d(0.5)
        self.maxpool2 = nn.MaxPool2d(3, stride=1)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3_dropout = nn.Dropout2d(0.5)
        self.maxpool3 = nn.MaxPool2d(3, stride=1)
        self.linear1 = nn.Linear(3625216, 32)
        self.linear2 = nn.Linear(32, 16)
    def forward(self, x):
        out = self.conv1_dropuot(self.maxpool1(self.conv1(x)))
        out = self.conv2_dropuot(self.maxpool2(self.comv2(out)))
        out = self.conv3_dropout(self.maxpool3(self.conv3(out)))
        out = out.view(out.size(0), -1)
        out = self.linear1(out)
        out = self.linear2(out)
        return out

# %%
# Creatting the model
model = CNN()

def loos(tested_out, known_out, non_obj_out, alpha):
    ''' This function is calcultating the loss
        :param tested_out: tensor
            The linear representation of the tested image
        :param known_out: tensor
            The linear representation of the knwon image
        :param non_obj_out: tensor
            The linear representation of the random image
        :param alpha: float
            The senzivity parameter
    '''
    norm1 = torch.norm(tested_out - known_out, p=2)
    norm2 = torch.norm(tested_out - non_obj_out, p=2)
    return max(norm1 - norm2 + alpha, torch.zeros(1, requires_grad=True))
# Definign the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.000001, momentum=0.5)

# %%
# Training process
for epoch in range(1):
    print("Epoch {}".format(epoch))
    train_loss = 0.0
    for triplet in snn_dataset:
        out1 = model(triplet[0].unsqueeze(1).permute(1, 0, 2, 3))
        out2 = model(triplet[1].unsqueeze(1).permute(1, 0, 2, 3))
        out3 = model(triplet[2].unsqueeze(1).permute(1, 0, 2, 3))
        loss = loos(out1, out2, out3, alpha=0.5)
        loss.backward()
        optimizer.step()
        print(loss)
# Out:
# Epoch 0
# tensor(0.6921, grad_fn=<AddBackward0>)
# tensor(0.4928, grad_fn=<AddBackward0>)
# tensor(0.6844, grad_fn=<AddBackward0>)
# tensor(0.5794, grad_fn=<AddBackward0>)
# tensor(0.5796, grad_fn=<AddBackward0>)
# tensor(0.6853, grad_fn=<AddBackward0>)
# tensor(0.4414, grad_fn=<AddBackward0>)
# tensor(0.2405, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(0.1481, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(0.7830, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(0.9435, grad_fn=<AddBackward0>)
# tensor(1.6644, grad_fn=<AddBackward0>)
# tensor(0.5113, grad_fn=<AddBackward0>)
# tensor(0.7444, grad_fn=<AddBackward0>)
# tensor(1.1098, grad_fn=<AddBackward0>)
# tensor(0.1726, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(1.3836, grad_fn=<AddBackward0>)
# tensor(2.0697, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(0.6385, grad_fn=<AddBackward0>)
# tensor(2.5312, grad_fn=<AddBackward0>)
# tensor(1.8563, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(0.7432, grad_fn=<AddBackward0>)
# tensor(1.1048, grad_fn=<AddBackward0>)
# tensor(0.7591, grad_fn=<AddBackward0>)
# tensor(1.2290, grad_fn=<AddBackward0>)
# tensor(1.4583, grad_fn=<AddBackward0>)
# tensor(2.3250, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(1.1076, grad_fn=<AddBackward0>)
# tensor(0.1232, grad_fn=<AddBackward0>)
# tensor(1.4801, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(3.4141, grad_fn=<AddBackward0>)
# tensor(3.2867, grad_fn=<AddBackward0>)
# tensor(1.9505, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(0.7642, grad_fn=<AddBackward0>)
# tensor(1.2962, grad_fn=<AddBackward0>)
# tensor(1.2279, grad_fn=<AddBackward0>)
# tensor(0.6702, grad_fn=<AddBackward0>)
# tensor(4.5493, grad_fn=<AddBackward0>)
# tensor(6.5257, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(0.7508, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(8.1513, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(0.1505, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(6.6408, grad_fn=<AddBackward0>)
# tensor(3.5483, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(4.9116, grad_fn=<AddBackward0>)
# tensor(5.0010, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(7.2894, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(10.0755, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(0.9761, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(9.6371, grad_fn=<AddBackward0>)
# tensor(9.7080, grad_fn=<AddBackward0>)
# tensor(11.8160, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(7.2448, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(3.0514, grad_fn=<AddBackward0>)
# tensor(18.2397, grad_fn=<AddBackward0>)
# tensor(7.3855, grad_fn=<AddBackward0>)
# tensor(1.8637, grad_fn=<AddBackward0>)
# tensor(3.3885, grad_fn=<AddBackward0>)
# tensor(9.7582, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(6.5761, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(13.3702, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(2.4274, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(4.9047, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(17.6748, grad_fn=<AddBackward0>)
# tensor(13.4613, grad_fn=<AddBackward0>)
# tensor(1.9748, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(6.9028, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(5.1206, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(11.8646, grad_fn=<AddBackward0>)
# tensor(5.0865, grad_fn=<AddBackward0>)
# tensor(19.0548, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(3.5845, grad_fn=<AddBackward0>)
# tensor(20.6922, grad_fn=<AddBackward0>)
# tensor(13.0655, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(2.0658, grad_fn=<AddBackward0>)
# tensor(8.3974, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(16.1990, grad_fn=<AddBackward0>)
# tensor(6.9252, grad_fn=<AddBackward0>)
# tensor(11.9319, grad_fn=<AddBackward0>)
# tensor(8.7640, grad_fn=<AddBackward0>)
# tensor(18.1486, grad_fn=<AddBackward0>)
# tensor(1.6062, grad_fn=<AddBackward0>)
# tensor(12.2773, grad_fn=<AddBackward0>)
# tensor(3.8529, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(16.6497, grad_fn=<AddBackward0>)
# tensor(1.3171, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(6.1463, grad_fn=<AddBackward0>)
# tensor(18.8794, grad_fn=<AddBackward0>)
# tensor(33.8032, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(16.0991, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(10.9259, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(10.3889, grad_fn=<AddBackward0>)
# tensor(1.3084, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(1.9904, grad_fn=<AddBackward0>)
# tensor(3.4468, grad_fn=<AddBackward0>)
# tensor(3.5154, grad_fn=<AddBackward0>)
# tensor(20.4461, grad_fn=<AddBackward0>)
# tensor([0.], requires_grad=True)
# tensor(16.6945, grad_fn=<AddBackward0>)

# %%
# Saving the model
torch.save(model, 'Valerica.pt')
